# %%
import numpy as np
from sklearn.datasets import make_blobs
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#sns.set_style('ticks')
sns.set_context('talk')

# %%
X,y = make_blobs(n_samples=100, n_features=2, centers=2, random_state=3, cluster_std=2.5)
X.shape
# Out:
# (100, 2)

# %%
fig,ax = plt.subplots(figsize=(8,6))
plt.scatter(X[:,0], X[:,1], c=y)
sns.despine()

# %%
sz = 80
Xtrain, ytrain = X[0:sz], y[0:sz]
Xtest, ytest = X[sz:], y[sz:]

# %%
clf = LogisticRegression(solver='lbfgs')

# %%
clf.fit(Xtrain, ytrain)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
clf.score(Xtest, ytest)
# Out:
# 0.95

# %%
probs = np.around(clf.predict_proba(Xtest),2)
probs
# Out:
# array([[1.  , 0.  ],
#        [0.91, 0.09],
#        [1.  , 0.  ],
#        [0.99, 0.01],
#        [0.02, 0.98],
#        [0.91, 0.09],
#        [0.92, 0.08],
#        [0.01, 0.99],
#        [0.84, 0.16],
#        [0.01, 0.99],
#        [1.  , 0.  ],
#        [0.02, 0.98],
#        [0.95, 0.05],
#        [0.96, 0.04],
#        [0.02, 0.98],
#        [0.1 , 0.9 ],
#        [0.99, 0.01],
#        [0.93, 0.07],
#        [0.03, 0.97],
#        [0.05, 0.95]])

# %%
from joblib import dump, load

# %%
dump(clf, 'model_1.joblib')
# Out:
# ['model_1.joblib']

# %%
clf2 = load('model_1.joblib')

# %%
xtest[0].reshape(1,2)
# Out:
# array([[1.89727609, 5.87252952]])

# %%
val = xtest[0].reshape(1,2)
val
# Out:
# array([[1.89727609, 5.87252952]])

# %%
clf2.predict(val)
# Out:
# array([0])

# %%
clf2.predict_proba(val)
# Out:
# array([[0.9949956, 0.0050044]])

# %%
val = [1,2]
val = np.array([val])

# %%
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-86-95039fbd75c1> in <module>
# ----> 1 import requests
#
# ModuleNotFoundError: No module named 'requests'
